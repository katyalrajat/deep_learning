# %% [markdown]
# <a href="https://colab.research.google.com/github/katyalrajat/deep_learning/blob/master/hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Notebook = "Hello_python"

# %%
## Let's get going

import pandas as pd

# %%
# Importing data to google

from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-356bf20a-4565-424c-b92f-9e7e15100350" name="files[]" multiple disabled />
#      <output id="result-356bf20a-4565-424c-b92f-9e7e15100350">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving wine-total.csv to wine-total.csv
# User uploaded file "wine-total.csv" with length 403530 bytes

# %%
df = pd.read_csv('wine-total.csv')
df.head(20)
# Out:
#     fixed acidity  volatile acidity  ...  quality_raw  quality_binary
# 0             7.0              0.27  ...            6               0
# 1             6.3              0.30  ...            6               0
# 2             8.1              0.28  ...            6               0
# 3             7.2              0.23  ...            6               0
# 4             7.2              0.23  ...            6               0
# 5             8.1              0.28  ...            6               0
# 6             6.2              0.32  ...            6               0
# 7             7.0              0.27  ...            6               0
# 8             6.3              0.30  ...            6               0
# 9             8.1              0.22  ...            6               0
# 10            8.1              0.27  ...            5               0
# 11            8.6              0.23  ...            5               0
# ...
